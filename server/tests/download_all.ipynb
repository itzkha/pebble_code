# %%
import paramiko
import normalizing_tools as tools

# %%
ssh = paramiko.SSHClient()
# automatically add keys without requiring human intervention
ssh.set_missing_host_key_policy( paramiko.AutoAddPolicy() )
ssh.connect('193.134.218.36', username='smartroot', password='dexterDEXTER0')

stdin, stdout, stderr = ssh.exec_command('cd smartdays/server/uploads; ls')
users = stdout.readlines()
ssh.close()

for user_code in users:
    print 'dowloading ', user_code.strip(), '...'
    tools.download_files(user_code.strip())
# Out:
# DEBUG:paramiko.transport:starting thread (client mode): 0xed1fd0L
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_6.6.1p1)
# ...
